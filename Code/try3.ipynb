# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# df=pd.read_csv('c:/
combined_df = pd.read_csv('C:/Users/Harsh/Desktop/npcl.4_id_data.csv')

# %%
combined_df=combined_df[['data.grid_reading_kwh','data.grid_kwh_unit','data.creation_time','data.status',
'data.meter_sr_no','data.energy_source','data.error_reason','data.R_voltage','data.Y_volatge',
'data.B_voltage', 'data.r_current', 'data.y_current','data.b_current','site_id',
'location_id','data.cumm_pf','data.frequency']]

# %%
combined_df=combined_df[combined_df['data.status']== "P"]

# %%
id=combined_df['location_id'].unique()
id
# Out:
# array([500000010232, 500000010632, 500000010732, 500000010832],
#       dtype=int64)

# %%
lst=[]
for each_id in id:
    df=combined_df[combined_df['location_id'] == each_id ]
    df['data.creation_time']=pd.to_datetime(df['data.creation_time'])
    df.set_index(['data.creation_time'],drop=True, inplace=True)


    lst.append(df)

# %%
df1=lst[0]

# %%
df1[(df1['data.grid_kwh_unit'] != 0) & (df1['data.error_reason'] == 'No Consumption')]
# Out:
#                      data.grid_reading_kwh  data.grid_kwh_unit data.status  \
# data.creation_time
# 2021-08-29 09:57:49                 2514.0                 1.0           P
# 2022-04-24 03:28:54                 4614.0                 1.0           P
# 2022-04-24 03:33:08                 4614.0                 1.0           P
# 2022-04-24 03:37:25                 4614.0                 1.0           P
# 2022-04-24 03:41:39                 4614.0                 1.0           P
# ...                                    ...                 ...         ...
# 2023-06-03 05:43:12                10073.0                 1.0           P
# 2023-06-03 05:51:52                10073.0                 1.0           P
# 2023-06-03 06:00:40                10073.0                 1.0           P
# 2023-06-03 06:09:23                10073.0                 1.0           P
# 2023-06-03 06:18:00                10073.0                 1.0           P
#
# ...

# %%
df2=lst[1]
df2[(df2['data.grid_kwh_unit'] != 0) & (df2['data.error_reason'] == 'No Consumption')]
# Out:
#                      data.grid_reading_kwh  data.grid_kwh_unit data.status  \
# data.creation_time
# 2021-08-29 09:57:25                 1844.0                 1.0           P
# 2022-04-24 03:15:49                 3809.0                 1.0           P
# 2022-04-24 03:20:03                 3809.0                 1.0           P
# 2022-04-24 03:24:16                 3809.0                 1.0           P
# 2022-04-24 03:28:30                 3809.0                 1.0           P
# ...                                    ...                 ...         ...
# 2023-06-03 06:08:38                 8845.0                 2.0           P
# 2023-06-03 06:17:15                 8845.0                 1.0           P
# 2023-06-03 06:25:54                 8845.0                 1.0           P
# 2023-06-03 06:34:31                 8845.0                 1.0           P
# 2023-06-03 06:43:14                 8845.0                 1.0           P
#
# ...

# %%
df3=lst[1]
df3[(df3['data.grid_kwh_unit'] != 0) & (df3['data.error_reason'] == 'No Consumption')]
# Out:
#                      data.grid_reading_kwh  data.grid_kwh_unit data.status  \
# data.creation_time
# 2021-08-29 09:57:25                 1844.0                 1.0           P
# 2022-04-24 03:15:49                 3809.0                 1.0           P
# 2022-04-24 03:20:03                 3809.0                 1.0           P
# 2022-04-24 03:24:16                 3809.0                 1.0           P
# 2022-04-24 03:28:30                 3809.0                 1.0           P
# ...                                    ...                 ...         ...
# 2023-06-03 06:08:38                 8845.0                 2.0           P
# 2023-06-03 06:17:15                 8845.0                 1.0           P
# 2023-06-03 06:25:54                 8845.0                 1.0           P
# 2023-06-03 06:34:31                 8845.0                 1.0           P
# 2023-06-03 06:43:14                 8845.0                 1.0           P
#
# ...
