# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.rcParams['figure.figsize']=(20,5)
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import pyarrow.parquet as pq

# %%
def sliderPlot(df1,i):
    fig = px.line(df1, y=df1[i] )
    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(count=2, label="2y", step="year", stepmode="backward"),
                dict(count=3, label="3y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        ))
    fig.show()

# %%
# df=pd.read_csv(r'C:/Users/Harsh/Downloads/DLMS Data/data.parquet')

# %%
table = pq.read_table('D:/Data_Files/DLMS Load Profile/data.parquet')

# Convert it to a Pandas DataFrame (optional)
dframe = table.to_pandas()

# %%
dframe['Kwh']=dframe['Kwh']/1000

# %%
dframe
# Out:
#                         sensor               Clock  R_Voltage  Y_Voltage  \
# 0      5f718c439c7a78.65267835 2022-11-18 00:30:00     6499.0     6514.0
# 1      5f718c439c7a78.65267835 2022-11-18 01:00:00     6520.0     6535.0
# 2      5f718c439c7a78.65267835 2022-11-18 01:30:00     6536.0     6551.0
# 3      5f718c439c7a78.65267835 2022-11-18 02:00:00     6576.0     6591.0
# 4      5f718c439c7a78.65267835 2022-11-18 02:30:00     6590.0     6605.0
# ...                        ...                 ...        ...        ...
# 38361  62a9920f75c931.62399458 2023-11-01 10:00:00     6021.0     6006.0
# 38362  62a9920f75c931.62399458 2023-11-01 10:30:00     6009.0     5995.0
# 38363  62a9920f75c931.62399458 2023-11-01 11:00:00     6024.0     6012.0
# 38364  62a9920f75c931.62399458 2023-11-01 11:30:00     6029.0     6016.0
# 38365  62a9920f75c931.62399458 2023-11-01 12:00:00     6019.0     6007.0
#
#        B_Voltage  R_Current  Y_Current  B_Current    Kwh
# 0         6473.0      27.74      27.42      25.57  261.3
# 1         6494.0      27.29      26.84      24.40  254.3
# 2         6511.0      27.06      27.00      24.37  254.8
# 3         6550.0      25.49      25.53      23.30  242.6
# 4         6564.0      25.21      24.74      23.09  238.9
# ...          ...        ...        ...        ...    ...
# 38361     5968.0      18.01      14.66      18.98  153.8
# 38362     5960.0      17.24      15.09      17.22  147.7
# 38363     5976.0      17.84      14.13      17.95  149.0
# 38364     5978.0      15.22      12.04      15.57  127.7
# 38365     5969.0      14.36      12.28      14.71  123.6
#
# [38366 rows x 9 columns]

# %%
id=dframe['sensor'].unique()

# %%
lst=[]
for location in id:
    df=dframe[dframe['sensor'] == location ]
    # df['Clock']=pd.to_datetime(df['Clock'])
    df.set_index(['Clock'],inplace=True,drop= True)
    df['2022-12-05 00:00:00':]
    filtered_df = df[((df['R_Voltage'] == 0) | (df['Y_Voltage'] == 0) | (df['B_Voltage'] == 0)) & 
                     ((df['R_Current'] == 0) | (df['Y_Current'] == 0) | (df['B_Current'] == 0))]
    filtered_df['Kwh'] = 0
    df.loc[filtered_df.index, :] = filtered_df
    df=df[['Kwh']].resample(rule='1H').sum()
    df['id']=location

    lst.append(df)

# %%
df=lst[0]
df
# Out:
#                         Kwh                       id
# Clock
# 2022-11-18 00:00:00   261.3  5f718c439c7a78.65267835
# 2022-11-18 01:00:00   509.1  5f718c439c7a78.65267835
# 2022-11-18 02:00:00   481.5  5f718c439c7a78.65267835
# 2022-11-18 03:00:00   472.2  5f718c439c7a78.65267835
# 2022-11-18 04:00:00   480.8  5f718c439c7a78.65267835
# ...                     ...                      ...
# 2023-10-31 22:00:00  1066.9  5f718c439c7a78.65267835
# 2023-10-31 23:00:00   975.5  5f718c439c7a78.65267835
# 2023-11-01 00:00:00   887.0  5f718c439c7a78.65267835
# 2023-11-01 01:00:00   815.1  5f718c439c7a78.65267835
# 2023-11-01 02:00:00   386.1  5f718c439c7a78.65267835
#
# [8355 rows x 2 columns]

# %%
df['id']=id[0]

# %%
df
# Out:
#                         Kwh                       id
# Clock
# 2022-11-18 00:00:00   261.3  5f718c439c7a78.65267835
# 2022-11-18 01:00:00   509.1  5f718c439c7a78.65267835
# 2022-11-18 02:00:00   481.5  5f718c439c7a78.65267835
# 2022-11-18 03:00:00   472.2  5f718c439c7a78.65267835
# 2022-11-18 04:00:00   480.8  5f718c439c7a78.65267835
# ...                     ...                      ...
# 2023-10-31 22:00:00  1066.9  5f718c439c7a78.65267835
# 2023-10-31 23:00:00   975.5  5f718c439c7a78.65267835
# 2023-11-01 00:00:00   887.0  5f718c439c7a78.65267835
# 2023-11-01 01:00:00   815.1  5f718c439c7a78.65267835
# 2023-11-01 02:00:00   386.1  5f718c439c7a78.65267835
#
# [8355 rows x 2 columns]

# %%
df
# Out:
#                         Kwh                       id
# Clock
# 2022-11-18 00:00:00   261.3  5f718c439c7a78.65267835
# 2022-11-18 01:00:00   509.1  5f718c439c7a78.65267835
# 2022-11-18 02:00:00   481.5  5f718c439c7a78.65267835
# 2022-11-18 03:00:00   472.2  5f718c439c7a78.65267835
# 2022-11-18 04:00:00   480.8  5f718c439c7a78.65267835
# ...                     ...                      ...
# 2023-10-31 22:00:00  1066.9  5f718c439c7a78.65267835
# 2023-10-31 23:00:00   975.5  5f718c439c7a78.65267835
# 2023-11-01 00:00:00   887.0  5f718c439c7a78.65267835
# 2023-11-01 01:00:00   815.1  5f718c439c7a78.65267835
# 2023-11-01 02:00:00   386.1  5f718c439c7a78.65267835
#
# [8355 rows x 2 columns]

# %%
df1=df[df['Kwh'] > 100]
df1
# Out:
#                         Kwh     kw_roll
# Clock
# 2022-11-19 22:00:00   722.8  739.150000
# 2022-11-19 23:00:00   653.1  738.645833
# 2022-11-20 00:00:00   639.9  740.629167
# 2022-11-20 01:00:00   530.1  740.787500
# 2022-11-20 02:00:00   504.6  740.741667
# ...                     ...         ...
# 2023-10-31 22:00:00  1066.9  985.366667
# 2023-10-31 23:00:00   975.5  983.391667
# 2023-11-01 00:00:00   887.0  981.958333
# 2023-11-01 01:00:00   815.1  980.387500
# 2023-11-01 02:00:00   386.1  962.662500
#
# [8256 rows x 2 columns]

# %%
df1['kw_roll']=df1['Kwh'].rolling(window=24).mean()

# %%
df1['Kwh'].plot(color='c')
df1['kw_roll'].plot(color='k')
# Out:
# <Axes: xlabel='Clock'>

# %%
df['Kwh'].plot(color='c')
df['kw_roll'].plot(color='k')
# Out:
# <Axes: xlabel='Clock'>

# %%
sliderPlot(df1,'Kwh')

# %%
sliderPlot(df,'Kwh')

# %%
df['kw_roll']=df['Kwh'].rolling(window=24).mean()
df.dropna(inplace=True)

# %%
result=adfuller(df['kw_roll'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -2.9942226917952484
# p-value: 0.0354374619219187
# Critical Values: {'1%': -3.431140588581714, '5%': -2.861889385098906, '10%': -2.566955972866476}

# %%
result=adfuller(df['Kwh'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -3.0819384477464498
# p-value: 0.027919020493812504
# Critical Values: {'1%': -3.4311403974666828, '5%': -2.861889300650604, '10%': -2.5669559279138685}

# %%
df['Kwh'].plot(color='c')
df['kw_roll'].plot(color='k')
# Out:
# <Axes: xlabel='Clock'>

# %%
df
# Out:
#                         Kwh                       id     kw_roll
# Clock
# 2022-11-18 23:00:00   665.2  5f718c439c7a78.65267835  717.695833
# 2022-11-19 00:00:00   592.3  5f718c439c7a78.65267835  731.487500
# 2022-11-19 01:00:00   526.3  5f718c439c7a78.65267835  732.204167
# 2022-11-19 02:00:00   505.7  5f718c439c7a78.65267835  733.212500
# 2022-11-19 03:00:00   487.4  5f718c439c7a78.65267835  733.845833
# ...                     ...                      ...         ...
# 2023-10-31 22:00:00  1066.9  5f718c439c7a78.65267835  985.366667
# 2023-10-31 23:00:00   975.5  5f718c439c7a78.65267835  983.391667
# 2023-11-01 00:00:00   887.0  5f718c439c7a78.65267835  981.958333
# 2023-11-01 01:00:00   815.1  5f718c439c7a78.65267835  980.387500
# 2023-11-01 02:00:00   386.1  5f718c439c7a78.65267835  962.662500
#
# [8332 rows x 3 columns]

# %%
add_resut=seasonal_decompose(df['Kwh'],model='additive',period=24)
add_resut.plot().suptitle('\n additive',fontsize=12)
dfs=pd.concat([add_resut.seasonal,add_resut.trend,add_resut.resid,add_resut.observed],axis=1)
dfs.columns=["seasonal",'trend','resid','Kwh']
dfs
# Out:
#                        seasonal  trend  resid     Kwh
# Clock
# 2022-11-18 23:00:00  294.459897    NaN    NaN   665.2
# 2022-11-19 00:00:00  200.423595    NaN    NaN   592.3
# 2022-11-19 01:00:00   67.757181    NaN    NaN   526.3
# 2022-11-19 02:00:00  -35.816663    NaN    NaN   505.7
# 2022-11-19 03:00:00 -107.220902    NaN    NaN   487.4
# ...                         ...    ...    ...     ...
# 2023-10-31 22:00:00  265.184144    NaN    NaN  1066.9
# 2023-10-31 23:00:00  294.459897    NaN    NaN   975.5
# 2023-11-01 00:00:00  200.423595    NaN    NaN   887.0
# 2023-11-01 01:00:00   67.757181    NaN    NaN   815.1
# 2023-11-01 02:00:00  -35.816663    NaN    NaN   386.1
#
# [8332 rows x 4 columns]

# %%
result=adfuller(dfs['Kwh'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -3.0948425262201607
# p-value: 0.026937226462572607
# Critical Values: {'1%': -3.4311382062666165, '5%': -2.8618883324211724, '10%': -2.56695541251651}

# %%
dfs['resid'].fillna(value=dfs['resid'].mean(),inplace=True)
dfs['trend'].fillna(value=dfs['trend'].mean(),inplace=True)

# %%
dfs['Kwh_t']=dfs['Kwh']-(dfs['resid']+dfs['seasonal'])
dfs['Kwh_n']=dfs['Kwh']-dfs['resid']

# %%
result=adfuller(dfs['Kwh'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -3.0948425262201607
# p-value: 0.026937226462572607
# Critical Values: {'1%': -3.4311382062666165, '5%': -2.8618883324211724, '10%': -2.56695541251651}

# %%
result=adfuller(dfs['trend'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -3.006541938142582
# p-value: 0.03428796562737771
# Critical Values: {'1%': -3.431138396323342, '5%': -2.8618884164019005, '10%': -2.5669554572202125}

# %%
result=adfuller(dfs['Kwh_t'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -2.2026446065798924
# p-value: 0.20528701780814307
# Critical Values: {'1%': -3.4311386815803457, '5%': -2.8618885424489475, '10%': -2.5669555243162}

# %%
result=adfuller(dfs['Kwh_n'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -1.8036260077386017
# p-value: 0.37866297324563725
# Critical Values: {'1%': -3.4311385864717447, '5%': -2.861888500423133, '10%': -2.5669555019454773}

# %%
dfs['rolling']=dfs['Kwh_n'].rolling(window=24).mean()

# %%
# dfs['rolling'].fillna(method='bfill',inplace=True)
dfs['inter']=dfs['Kwh_n'].interpolate()

# %%
dfs['diff']=dfs['Kwh_n']-dfs['Kwh_n'].shift(1)

# %%
dfs
# Out:
#                        seasonal        trend     resid     Kwh       Kwh_t  \
# Clock
# 2022-11-18 23:00:00  294.459897  1232.203683  0.050538   665.2  370.689565
# 2022-11-19 00:00:00  200.423595  1232.203683  0.050538   592.3  391.825867
# 2022-11-19 01:00:00   67.757181  1232.203683  0.050538   526.3  458.492281
# 2022-11-19 02:00:00  -35.816663  1232.203683  0.050538   505.7  541.466125
# 2022-11-19 03:00:00 -107.220902  1232.203683  0.050538   487.4  594.570364
# ...                         ...          ...       ...     ...         ...
# 2023-10-31 22:00:00  265.184144  1232.203683  0.050538  1066.9  801.665318
# 2023-10-31 23:00:00  294.459897  1232.203683  0.050538   975.5  680.989565
# 2023-11-01 00:00:00  200.423595  1232.203683  0.050538   887.0  686.525867
# 2023-11-01 01:00:00   67.757181  1232.203683  0.050538   815.1  747.292281
# 2023-11-01 02:00:00  -35.816663  1232.203683  0.050538   386.1  421.866125
#
#                            Kwh_n     rolling        inter   diff
# Clock
# 2022-11-18 23:00:00   665.149462         NaN   665.149462    NaN
# 2022-11-19 00:00:00   592.249462         NaN   592.249462  -72.9
# 2022-11-19 01:00:00   526.249462         NaN   526.249462  -66.0
# 2022-11-19 02:00:00   505.649462         NaN   505.649462  -20.6
# 2022-11-19 03:00:00   487.349462         NaN   487.349462  -18.3
# ...                          ...         ...          ...    ...
# 2023-10-31 22:00:00  1066.849462  983.762008  1066.849462    7.6
# 2023-10-31 23:00:00   975.449462  971.107320   975.449462  -91.4
# 2023-11-01 00:00:00   886.949462  958.856054   886.949462  -88.5
# 2023-11-01 01:00:00   815.049462  949.246791   815.049462  -71.9
# 2023-11-01 02:00:00   386.049462  926.091040   386.049462 -429.0
#
# [8332 rows x 9 columns]

# %%
dfs.dropna(inplace=True)

# %%
result=adfuller(dfs['inter'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -1.9536974191158853
# p-value: 0.3072366354220939
# Critical Values: {'1%': -3.431140875427615, '5%': -2.861889511847948, '10%': -2.5669560403361578}

# %%
result=adfuller(dfs['rolling'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -1.915293821417094
# p-value: 0.32490097103274596
# Critical Values: {'1%': -3.431140875427615, '5%': -2.861889511847948, '10%': -2.5669560403361578}

# %%
result=adfuller(dfs['diff'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -14.940696585649638
# p-value: 1.3239564775105056e-27
# Critical Values: {'1%': -3.431140875427615, '5%': -2.861889511847948, '10%': -2.5669560403361578}

# %%
dfs['kw_roll']=dfs['Kwh'].rolling(window=24).mean()

# %%
dfs['rolling'].plot()
# Out:
# <Axes: xlabel='Clock'>

# %%
dfs['Kwh'].plot()
dfs['Kwh_t'].plot()
dfs['rolling'].plot()
# Out:
# <Axes: xlabel='Clock'>

# %%
dfs['Kwh'].plot()
dfs['Kwh_n'].plot()
# Out:
# <Axes: xlabel='Clock'>

# %%
df=df[['Kwh']].resample(rule='1H').sum()
add_resut=seasonal_decompose(df['Kwh'],model='additive',period=24)
# add_resut.plot().suptitle('\n additive',fontsize=12)
dfs=pd.concat([add_resut.seasonal,add_resut.trend,add_resut.resid,add_resut.observed],axis=1)
dfs.columns=["seasonal",'trend','resid','Kwh']
dfs['resid'].fillna(value=dfs['resid'].mean(),inplace=True)
dfs['trend'].fillna(value=dfs['trend'].mean(),inplace=True)
dfs['Kwh_n']=dfs['Kwh']-dfs['resid']

# %%
dfs
# Out:
#                        seasonal        trend     resid     Kwh        Kwh_n
# Clock
# 2022-11-18 23:00:00  294.459897  1232.203683  0.050538   665.2   665.149462
# 2022-11-19 00:00:00  200.423595  1232.203683  0.050538   592.3   592.249462
# 2022-11-19 01:00:00   67.757181  1232.203683  0.050538   526.3   526.249462
# 2022-11-19 02:00:00  -35.816663  1232.203683  0.050538   505.7   505.649462
# 2022-11-19 03:00:00 -107.220902  1232.203683  0.050538   487.4   487.349462
# ...                         ...          ...       ...     ...          ...
# 2023-10-31 22:00:00  265.184144  1232.203683  0.050538  1066.9  1066.849462
# 2023-10-31 23:00:00  294.459897  1232.203683  0.050538   975.5   975.449462
# 2023-11-01 00:00:00  200.423595  1232.203683  0.050538   887.0   886.949462
# 2023-11-01 01:00:00   67.757181  1232.203683  0.050538   815.1   815.049462
# 2023-11-01 02:00:00  -35.816663  1232.203683  0.050538   386.1   386.049462
#
# [8332 rows x 5 columns]

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8332 entries, 2022-11-18 23:00:00 to 2023-11-01 02:00:00
# Freq: H
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   seasonal  8332 non-null   float64
#  1   trend     8332 non-null   float64
#  2   resid     8332 non-null   float64
#  3   Kwh       8332 non-null   float64
#  4   Kwh_n     8332 non-null   float64
# dtypes: float64(5)
# memory usage: 390.6 KB

# %%
# dfs=dfs.resample(rule='30min').sum()

# %%
dfs['Kwh'].plot()
# Out:
# <Axes: xlabel='Clock'>

# %%
dfs['Kwh_n'].plot()
# Out:
# <Axes: xlabel='Clock'>

# %%
result=adfuller(dfs['Kwh_n'],autolag='AIC')
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -1.8036260077386017
# p-value: 0.37866297324563725
# Critical Values: {'1%': -3.4311385864717447, '5%': -2.861888500423133, '10%': -2.5669555019454773}

# %%
column_means = df_s.mean()

# Fill null values with respective column means
df_s = df_s.fillna(column_means)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Harsh_git\DLMS_Load_Profile\Test\Test3.ipynb Cell 60 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Harsh_git/DLMS_Load_Profile/Test/Test3.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> column_means = df_s.mean()
#       <a href='vscode-notebook-cell:/d%3A/Harsh_git/DLMS_Load_Profile/Test/Test3.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a> # Fill null values with respective column means
#       <a href='vscode-notebook-cell:/d%3A/Harsh_git/DLMS_Load_Profile/Test/Test3.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a> df_s = df_s.fillna(column_means)
#
# NameError: name 'df_s' is not defined

# %%
df_s.head()

# %%
df_s.info()

# %%
df_s.

# %%
df_s['Kwh_n']=df_s[df_s['Kwh']-df_s['resid']]

# %%
df_s.fillna()

# %%
column_means = df_s.mean()

# %%
df_s_filled = df_s.fillna(column_means)

# %%
df_s_filled

# %%
df_s_filled['Kwh_n']=df_s_filled[df_s_filled['kwh']-df_s_filled['resid']]

# %%
df_s

# %%
df_s = df_s.reset_index(drop=True)

# Calculate column means
column_means = df_s.mean()

# Fill null values with respective column means
df_s = df_s.fillna(column_means)

# %%
df_s

# %%
# df_s['Kwh_n']=df_s[df_s['kwh']-df_s['resid']]
df_s.info()

# %%
df1=df1[['Kwh']].resample(rule='30Min').sum()
df1

# %%
df1.isna().sum()

# %%
df2=lst[1]
df2

# %%
df2['2022-09-07 15:30:00':'2022-12-04 00:00:00']

# %%
df2_s=df2[['Kwh']].resample(rule='30Min').max()
df2_s

# %%
df2_s.isna().sum()

# %%
result = df2 - df2_s

# %%
result['Kwh'].unique()

# %%
sliderPlot(df2_s,'Kwh')

# %%
df2_s['Kwh'].plot()

# %%
indices_with_missing_values = df2_s[df2_s.isnull().any(axis=1)].index

# Display the indices
print(indices_with_missing_values)

# %%
df2=df2[['Kwh']].resample(rule='30Min').mean()
df2

# %%
df2.isna().sum()
