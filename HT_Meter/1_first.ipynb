# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:/Users/Harsh/Desktop/HTMeter_data/NPCL-data_log (1).xlsx')

# %%
df.columns
# Out:
# Index(['site_id', 'dic_id', 'device_sr_no', 'meter_timestamp', 'KWh', 'KVAh',
#        'instant_cum_KW', 'instant_cum_KVA', 'max_demand_KW', 'max_demand_KVA',
#        'max_demand_time', 'R_Voltage', 'Y_Voltage', 'B_Voltage', 'R_Current',
#        'Y_Current', 'B_Current', 'cumm_PF', 'creation_time', 'error_reason',
#        'status'],
#       dtype='object')

# %%
df
# Out:
#                       site_id                         dic_id device_sr_no  \
# 0     5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 1     5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 2     5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 3     5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 4     5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# ...                       ...                            ...          ...
# 6630  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 6631  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 6632  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 6633  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 6634  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
#
#          meter_timestamp       KWh      KVAh  instant_cum_KW  instant_cum_KVA  \
# ...

# %%
df[df['cumm_PF']==1]
# Out:
#                       site_id                         dic_id device_sr_no  \
# 45    5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 87    5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 88    5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 89    5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 90    5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 647   5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 648   5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 820   5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 1100  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 1581  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 1615  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# 1868  5f6de3495e1d33.21320807  38-30-34-31-31-36-34-37-35-33     SHT00302
# ...
